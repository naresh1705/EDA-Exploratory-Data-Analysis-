# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv"
population_data = pd.read_csv(url, skiprows=4)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(population_data.head())

# Check for missing values
print("\nMissing values per column:")
print(population_data.isnull().sum())

# Drop unnecessary columns and rows with missing values
population_data = population_data.dropna(axis=1, how='all')
population_data = population_data.dropna(axis=0, subset=['Country Name'])

# Rename columns for easier access
population_data.rename(columns={'Country Name': 'Country'}, inplace=True)

# Summary statistics for the most recent year available
most_recent_year = population_data.columns[-1]
print(f"\nSummary statistics for the year {most_recent_year}:")
print(population_data[most_recent_year].describe())

# Histogram of population distribution
plt.figure(figsize=(10, 6))
sns.histplot(population_data[most_recent_year].dropna(), bins=30, kde=True)
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title(f'Distribution of Population in {most_recent_year}')
plt.show()

# Bar chart of top 10 most populous countries
top_10_countries = population_data.nlargest(10, most_recent_year)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_countries['Country'], y=top_10_countries[most_recent_year] / 1e6, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population (millions)')
plt.title(f'Top 10 Most Populous Countries in {most_recent_year}')
plt.show()

# Line plot of global population growth over time
global_population = population_data[population_data['Country'] == 'World'].dropna(axis=1, how='all').melt(id_vars='Country', var_name='Year', value_name='Population')
global_population['Year'] = global_population['Year'].astype(int)

plt.figure(figsize=(14, 8))
sns.lineplot(data=global_population, x='Year', y='Population')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Global Population Growth Over Time')
plt.show()

# Additional analysis: population growth rates
population_data['Growth Rate'] = population_data[most_recent_year] / population_data[population_data.columns[-2]] - 1

# Plotting population growth rates
plt.figure(figsize=(12, 8))
sns.histplot(population_data['Growth Rate'].dropna(), bins=30, kde=True, color='green')
plt.xlabel('Population Growth Rate')
plt.ylabel('Frequency')
plt.title('Distribution of Population Growth Rates')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-33ac095a77b5> in <cell line: 7>()
#       5 # Load the dataset
#       6 url = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv"
# ----> 7 population_data = pd.read_csv(url, skiprows=4)
#       8
#       9 # Display the first few rows of the dataset
#
# ...

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
url = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv"
population_data = pd.read_csv(url, skiprows=4)

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(population_data.head())

# Check for missing values
print("\nMissing values per column:")
print(population_data.isnull().sum())

# Drop unnecessary columns and rows with missing values
population_data = population_data.dropna(axis=1, how='all')
population_data = population_data.dropna(axis=0, subset=['Country Name'])

# Rename columns for easier access
population_data.rename(columns={'Country Name': 'Country'}, inplace=True)

# Summary statistics for the most recent year available
most_recent_year = population_data.columns[-1]
print(f"\nSummary statistics for the year {most_recent_year}:")
print(population_data[most_recent_year].describe())

# Histogram of population distribution
plt.figure(figsize=(10, 6))
sns.histplot(population_data[most_recent_year].dropna(), bins=30, kde=True)
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title(f'Distribution of Population in {most_recent_year}')
plt.show()

# Bar chart of top 10 most populous countries
top_10_countries = population_data.nlargest(10, most_recent_year)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_countries['Country'], y=top_10_countries[most_recent_year] / 1e6, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population (millions)')
plt.title(f'Top 10 Most Populous Countries in {most_recent_year}')
plt.show()

# Line plot of global population growth over time
global_population = population_data[population_data['Country'] == 'World'].dropna(axis=1, how='all').melt(id_vars='Country', var_name='Year', value_name='Population')
global_population['Year'] = global_population['Year'].astype(int)

plt.figure(figsize=(14, 8))
sns.lineplot(data=global_population, x='Year', y='Population')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Global Population Growth Over Time')
plt.show()

# Additional analysis: population growth rates
population_data['Growth Rate'] = population_data[most_recent_year] / population_data[population_data.columns[-2]] - 1

# Plotting population growth rates
plt.figure(figsize=(12, 8))
sns.histplot(population_data['Growth Rate'].dropna(), bins=30, kde=True, color='green')
plt.xlabel('Population Growth Rate')
plt.ylabel('Frequency')
plt.title('Distribution of Population Growth Rates')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-3-3a2553bbe659> in <cell line: 8>()
#       6 # Load the dataset
#       7 url = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv"
# ----> 8 population_data = pd.read_csv(url, skiprows=4)
#       9
#      10 # Display the first few rows of the dataset
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset, specifying the encoding
url = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv"
population_data = pd.read_csv(url, skiprows=4, encoding='latin1') # Try 'latin1' encoding
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-4e45ef221ad8> in <cell line: 7>()
#       5 # Load the dataset, specifying the encoding
#       6 url = "https://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv"
# ----> 7 population_data = pd.read_csv(url, skiprows=4, encoding='latin1') # Try 'latin1' encoding
#       8
#
# ...

# %%
# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(population_data.head())

# Check for missing values
print("\nMissing values per column:")
print(population_data.isnull().sum())

# Drop unnecessary columns and rows with missing values
population_data = population_data.dropna(axis=1, how='all')
population_data = population_data.dropna(axis=0, subset=['Country Name'])

# Rename columns for easier access
population_data.rename(columns={'Country Name': 'Country'}, inplace=True)

# Summary statistics for the most recent year available
most_recent_year = population_data.columns[-1]
print(f"\nSummary statistics for the year {most_recent_year}:")
print(population_data[most_recent_year].describe())

# Histogram of population distribution
plt.figure(figsize=(10, 6))
sns.histplot(population_data[most_recent_year].dropna(), bins=30, kde=True)
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.title(f'Distribution of Population in {most_recent_year}')
plt.show()

# Bar chart of top 10 most populous countries
top_10_countries = population_data.nlargest(10, most_recent_year)

plt.figure(figsize=(12, 8))
sns.barplot(x=top_10_countries['Country'], y=top_10_countries[most_recent_year] / 1e6, palette='viridis')
plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population (millions)')
plt.title(f'Top 10 Most Populous Countries in {most_recent_year}')
plt.show()

# Line plot of global population growth over time
global_population = population_data[population_data['Country'] == 'World'].dropna(axis=1, how='all').melt(id_vars='Country', var_name='Year', value_name='Population')
global_population['Year'] = global_population['Year'].astype(int)

plt.figure(figsize=(14, 8))
sns.lineplot(data=global_population, x='Year', y='Population')
plt.xlabel('Year')
plt.ylabel('Population')
plt.title('Global Population Growth Over Time')
plt.show()

# Additional analysis: population growth rates
population_data['Growth Rate'] = population_data[most_recent_year] / population_data[population_data.columns[-2]] - 1

# Plotting population growth rates
plt.figure(figsize=(12, 8))
sns.histplot(population_data['Growth Rate'].dropna(), bins=30, kde=True, color='green')
plt.xlabel('Population Growth Rate')
plt.ylabel('Frequency')
plt.title('Distribution of Population Growth Rates')
plt.show()

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the Titanic dataset from seaborn
titanic_data = sns.load_dataset('titanic')

# Display the first few rows of the dataset
print("First few rows of the dataset:")
print(titanic_data.head())

# Check for missing values
print("\nMissing values per column:")
print(titanic_data.isnull().sum())

# Drop rows with missing 'embarked' values
titanic_data = titanic_data.dropna(subset=['embarked'])

# Fill missing 'age' values with the median age
titanic_data['age'] = titanic_data['age'].fillna(titanic_data['age'].median())

# Drop the 'deck' column due to many missing values
titanic_data = titanic_data.drop(columns=['deck'])

# Fill missing 'embark_town' values with the mode
titanic_data['embark_town'] = titanic_data['embark_town'].fillna(titanic_data['embark_town'].mode()[0])

# Fill missing 'fare' values with the median fare
titanic_data['fare'] = titanic_data['fare'].fillna(titanic_data['fare'].median())

# Summary statistics
print("\nSummary statistics:")
print(titanic_data.describe())

# Distribution of ages
plt.figure(figsize=(10, 6))
sns.histplot(titanic_data['age'], bins=30, kde=True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Distribution of Age')
plt.show()

# Count plot of survivors
plt.figure(figsize=(10, 6))
sns.countplot(x='survived', data=titanic_data)
plt.xlabel('Survived')
plt.ylabel('Count')
plt.title('Survival Count')
plt.show()

# Bar plot of survival rate by class
plt.figure(figsize=(10, 6))
sns.barplot(x='pclass', y='survived', data=titanic_data)
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Passenger Class')
plt.show()

# Bar plot of survival rate by sex
plt.figure(figsize=(10, 6))
sns.barplot(x='sex', y='survived', data=titanic_data)
plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Sex')
plt.show()

# Pair plot to see pairwise relationships
sns.pairplot(titanic_data, hue='survived', diag_kind='kde')
plt.suptitle('Pairwise Relationships in the Titanic Dataset', y=1.02)
plt.show()

# Heatmap of the correlation matrix
plt.figure(figsize=(12, 8))
# Select only numerical columns for correlation calculation
numerical_data = titanic_data.select_dtypes(include=['number'])
sns.heatmap(numerical_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# First few rows of the dataset:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#
# Missing values per column:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# ...
